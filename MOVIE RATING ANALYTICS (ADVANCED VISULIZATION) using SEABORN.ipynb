# %% [markdown]
# **MOVING RATING ANALYSIS (ADVANCE VISULIZATION)**

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\JAGRUTI'

# %%
movies = pd.read_csv(r'C:\Users\JAGRUTI\Downloads\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.tail()
# Out:
#                 Film     Genre  CriticRatings  AudienceRatings  \
# 554    Your Highness    Comedy             26               36
# 555  Youth in Revolt    Comedy             68               52
# 556           Zodiac  Thriller             89               73
# 557      Zombieland     Action             90               87
# 558        Zookeeper    Comedy             14               42
#
#      BudgetMillions  Year
# 554              50  2011
# 555              18  2009
# 556              65  2007
# 557              24  2009
# 558              80  2011

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer   Comedy             87               81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category') #to change dtype object into category

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies
# Out:
#                       Film      Genre  CriticRatings  AudienceRatings  \
# 0    (500) Days of Summer      Comedy             87               81
# 1              10,000 B.C.  Adventure              9               44
# 2               12 Rounds      Action             30               52
# 3                127 Hours  Adventure             93               84
# 4                17 Again      Comedy             55               70
# ..                     ...        ...            ...              ...
# 554          Your Highness     Comedy             26               36
# 555        Youth in Revolt     Comedy             68               52
# 556                 Zodiac   Thriller             89               73
# 557            Zombieland      Action             90               87
# 558              Zookeeper     Comedy             14               42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
movies.Film.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# **2.0 PLOTS**

# %%
from matplotlib import pyplot as plt #visulization
import seaborn as sns #advance visulization
# %matplotlib inline #all the should be inside the line
import warnings
warnings.filterwarnings('ignore')  #to ignore warnings
# Out:
# UsageError: unrecognized arguments: #all the should be inside the line

# %%
x = sns.jointplot(data=movies, x='CriticRatings', y='AudienceRatings')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='reg')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='hex')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='kde')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='hist')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='resid')

# %%
x = sns.jointplot(data=movies, x='CriticRatings',y='AudienceRatings',kind='scatter')

# %%
m= sns.distplot(movies.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %% [markdown]
# # <<< chat - 2
# # Creating stacked histograms & this is bit tough to understand

# %%
m2=sns.distplot(movies.AudienceRatings, bins=15)

# %%
n1=plt.hist(movies.AudienceRatings,bins=20)

# %%
sns.set_style('white')
n1=plt.hist(movies.AudienceRatings, bins=10)

# %%
n1=plt.hist(movies.CriticRatings, bins=15)

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
movies.head()

# %%
#movies.genre.unique()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
         movies[movies.Genre=='Thriller'].BudgetMillions,\
         movies[movies.Genre=='Drama'].BudgetMillions,\
          movies[movies.Genre=='Comedy'].BudgetMillions],
         bins=20,stacked= True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1=sns.lmplot(data=movies,x='CriticRatings',y='AudienceRatings',\
                fit_reg=False)

# %%
vis1=sns.lmplot(data=movies,x='CriticRatings',y='AudienceRatings',\
                fit_reg=False,hue='Genre')

# %%
vis1=sns.lmplot(data=movies,x='CriticRatings',y='AudienceRatings',\
                fit_reg=False,hue='Genre', aspect=1)

# %%
# Kernal Density Estimate plot ( KDE PLOT)
# how can i visulize audience rating & critics rating using scatterplot

# %%
k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings)

# %%
k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
# Out:
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\2289167729.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\2289167729.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')

# %%
k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Blues')
# Out:
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\2627592623.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Blues')
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\2627592623.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Blues')

# %%
k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade_lowest=False,cmap='Blues')
# Out:
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\3425303175.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade_lowest=False,cmap='Blues')

# %%
sns.set_style('dark')
k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade_lowest=False,cmap='Blues')
# Out:
# C:\Users\JAGRUTI\AppData\Local\Temp\ipykernel_14888\1219062538.py:2: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(x=movies.CriticRatings,y=movies.AudienceRatings,shade_lowest=False,cmap='Blues')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRatings)

# %%
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRatings)

# %%
#subplot
f, ax = plt.subplots(1,2, figsize = (12,6))
#f ax= plt.subplots(3,3,figsize = (12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRatings,ax=axes[0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRatings,ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRatings'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRatings'>],
#       dtype=object)

# %%
#box plots

w=sns.boxplot(data=movies, x='Genre',y='CriticRatings',hue='Genre')

# %%
z=sns.violinplot(data=movies, x='Genre', y='CriticRatings',hue='Genre')
plt.show()

# %%
#Creating a Facet grid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')

# %%
plt.scatter(x=movies.CriticRatings,y=movies.AudienceRatings)

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings' )
#scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat.
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings',**kws )

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))
k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRatings,ax=axes[0,1])
k1.set(xlim=(-20,160))
# Out:
# [(-20.0, 160.0)]
